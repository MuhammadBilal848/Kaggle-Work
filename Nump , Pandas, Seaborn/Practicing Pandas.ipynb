# %%
import pandas as pd
import numpy as np
import os

# %%
a = pd.Series(['a','b','c','d'])
a
# Out:
# 0    a
# 1    b
# 2    c
# 3    d
# dtype: object

# %%
a = pd.Series(['a','b','c','d'],[3,2,1,0])
a[3]
# Out:
# 'a'

# %%
a.index
# Out:
# Int64Index([3, 2, 1, 0], dtype='int64')

# %%
a.values
# Out:
# array(['a', 'b', 'c', 'd'], dtype=object)

# %%
a.index = [0,1,2,3]

# %%
a[3]
# Out:
# 'd'

# %%
a[a.index>1]
# Out:
# 2    c
# 3    d
# dtype: object

# %%
mySeries = pd.Series([3,-5,7,4], index=['a','b','c','d'])
type(mySeries)
# Out:
# pandas.core.series.Series

# %%
a = ({'Country':['Pakistan','India','Russia'] ,
                  'Capital':['Islamabad','Dehli','Moscow'],
                  'Population':['25M','1B','800M']}
                  )
a = pd.Series(a)
a
# Out:
# Country        [Pakistan, India, Russia]
# Capital       [Islamabad, Dehli, Moscow]
# Population               [25M, 1B, 800M]
# dtype: object

# %%
city = { 'Karachi':3780 , 
        'Lahore':1772 ,
        'Mianwali':5840 , 
        'Hyderabad':292 }
city0 = pd.Series(city)
print(city0)
# Out:
# Karachi      3780
# Lahore       1772
# Mianwali     5840
# Hyderabad     292
# dtype: int64

# %%
a = ({'Country':['Pakistan','India','Russia'] ,
                  'Capital':['Islamabad','Dehli','Moscow'],
                  'Population':['25M','1B','800M']}
                  )
a = pd.Series(a.keys() , index=a.values())
a
# Out:
# [Pakistan, India, Russia]     (Country, Capital, Population)
# [Islamabad, Dehli, Moscow]    (Country, Capital, Population)
# [25M, 1B, 800M]               (Country, Capital, Population)
# dtype: object

# %%
a = ({'Country':['Pakistan','India',np.nan] ,
                  'Capital':['Islamabad','Dehli','Moscow'],
                  'Population':['25M','1B','800M']}
                  )
a = pd.Series(a)
pd.isna(a)
# Out:
# Country       False
# Capital       False
# Population    False
# dtype: bool

# %%
sandw = pd.Series([50,60,70,80,90,100,0],index = ['Mon','Tue','Wed','Thu','Fri','Sat','Sun'],name = 'Canteen Sandwiches')
sandw.index.name = 'Days'
print(sandw)
# Out:
# Days
# Mon     50
# Tue     60
# Wed     70
# Thu     80
# Fri     90
# Sat    100
# Sun      0
# Name: Canteen Sandwiches, dtype: int64

# %%
a = pd.Series([1,2,3,np.nan,5,6])
a
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    NaN
# 4    5.0
# 5    6.0
# dtype: float64

# %%
pd.isna(a)
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5    False
# dtype: bool

# %%
pd.isnull(a)
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5    False
# dtype: bool

# %%
a = pd.DataFrame({'Country':['Pakistan','India','Russia'] ,
                  'Capital':['Islamabad','Dehli','Moscow'],
                  'Population':['25M','1B','800M']}
                  )
a
# Out:
#     Country    Capital Population
# 0  Pakistan  Islamabad        25M
# 1     India      Dehli         1B
# 2    Russia     Moscow       800M

# %%
a = pd.Series((['Pakistan','India','Russia'] ,
                  ['Islamabad','Dehli','Moscow'],
                  ['25M','1B','800M'])
                  )
a
# Out:
# 0     [Pakistan, India, Russia]
# 1    [Islamabad, Dehli, Moscow]
# 2               [25M, 1B, 800M]
# dtype: object

# %%
os.listdir()
df = pd.read_csv('C:\\Users\\Muhammad Bilal\DJIA_table.csv')

# %%
df
# Out:
#             Date          Open          High           Low         Close  \
# 0     2016-07-01  17924.240234  18002.380859  17916.910156  17949.369141
# 1     2016-06-30  17712.759766  17930.609375  17711.800781  17929.990234
# 2     2016-06-29  17456.019531  17704.509766  17456.019531  17694.679688
# 3     2016-06-28  17190.509766  17409.720703  17190.509766  17409.720703
# 4     2016-06-27  17355.210938  17355.210938  17063.080078  17140.240234
# 5     2016-06-24  17946.630859  17946.630859  17356.339844  17400.750000
# 6     2016-06-23  17844.109375  18011.070312  17844.109375  18011.070312
# 7     2016-06-22  17832.669922  17920.160156  17770.359375  17780.830078
# 8     2016-06-21  17827.330078  17877.839844  17799.800781  17829.730469
# 9     2016-06-20  17736.869141  17946.359375  17736.869141  17804.869141
# 10    2016-06-17  17733.439453  17733.439453  17602.779297  17675.160156
# 11    2016-06-16  17602.230469  17754.910156  17471.289062  17733.099609
# ...

# %%
pd.DataFrame(np.random.randn(20,5))
# Out:
#            0         1         2         3         4
# 0  -0.242119  0.649651  0.367095 -0.783353  0.170876
# 1  -0.117038 -0.806905 -0.132770  0.439850 -0.783761
# 2   0.542836  0.291779  0.095042  1.537063  0.967618
# 3  -0.869146  0.167125 -0.042434  2.880635  0.522474
# 4   0.747331 -0.655279  0.888068 -0.914000 -0.522846
# 5  -1.794122 -0.000626  0.143658 -1.034495  1.783582
# 6   0.429375 -0.421118 -0.979815  0.102754  1.736266
# 7   1.557259 -0.516027  0.317549 -1.367390 -0.279480
# 8   1.194864  1.489450 -1.901000 -0.817032  0.444291
# 9   0.563597  0.481512  0.121241 -0.294313  1.794724
# 10  1.332592 -1.286334  0.886366  0.308149 -1.065914
# 11 -3.138490 -0.848376  0.203479  1.141101 -0.155089
# 12  0.022920  3.085571 -0.558802  1.039646 -1.874952
# 13 -0.955483 -0.423864 -2.232698  1.782689 -0.230749
# 14  0.057577 -0.145844  0.266368  0.191324  1.829333
# 15  0.372641  1.762092 -1.070861 -0.723693  0.578145
# 16  0.276477  1.891704  2.221039  0.503951 -0.216399
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1989 entries, 0 to 1988
# Data columns (total 7 columns):
# Date         1989 non-null object
# Open         1989 non-null float64
# High         1989 non-null float64
# Low          1989 non-null float64
# Close        1989 non-null float64
# Volume       1989 non-null int64
# Adj Close    1989 non-null float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 108.9+ KB

# %%
df.shape
# Out:
# (1989, 7)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1989, step=1)

# %%
df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Adj Close'], dtype='object')

# %%
df.count()
# Out:
# Date         1989
# Open         1989
# High         1989
# Low          1989
# Close        1989
# Volume       1989
# Adj Close    1989
# dtype: int64

# %%
df.sum()
# Out:
# Date         2016-07-012016-06-302016-06-292016-06-282016-0...
# Open                                               2.67702e+07
# High                                               2.69337e+07
# Low                                                2.65988e+07
# Close                                               2.6778e+07
# Volume                                            323831020000
# Adj Close                                           2.6778e+07
# dtype: object

# %%
df.head()
# Out:
#          Date          Open          High           Low         Close  \
# 0  2016-07-01  17924.240234  18002.380859  17916.910156  17949.369141
# 1  2016-06-30  17712.759766  17930.609375  17711.800781  17929.990234
# 2  2016-06-29  17456.019531  17704.509766  17456.019531  17694.679688
# 3  2016-06-28  17190.509766  17409.720703  17190.509766  17409.720703
# 4  2016-06-27  17355.210938  17355.210938  17063.080078  17140.240234
#
#       Volume     Adj Close
# 0   82160000  17949.369141
# 1  133030000  17929.990234
# 2  106380000  17694.679688
# 3  112190000  17409.720703
# 4  138740000  17140.240234

# %%
df.cumsum().head()
# Out:
#                                                 Date     Open     High  \
# 0                                         2016-07-01  17924.2  18002.4
# 1                               2016-07-012016-06-30    35637    35933
# 2                     2016-07-012016-06-302016-06-29    53093  53637.5
# 3           2016-07-012016-06-302016-06-292016-06-28  70283.5  71047.2
# 4  2016-07-012016-06-302016-06-292016-06-282016-0...  87638.7  88402.4
#
#        Low    Close     Volume Adj Close
# 0  17916.9  17949.4   82160000   17949.4
# 1  35628.7  35879.4  215190000   35879.4
# 2  53084.7    53574  321570000     53574
# 3  70275.2  70983.8  433760000   70983.8
# 4  87338.3    88124  572500000     88124

# %%
df['Volume'].cumsum().head()
# Out:
# 0     82160000
# 1    215190000
# 2    321570000
# 3    433760000
# 4    572500000
# Name: Volume, dtype: int64

# %%
df.min()
# Out:
# Date         2008-08-08
# Open            6547.01
# High            6709.61
# Low             6469.95
# Close           6547.05
# Volume          8410000
# Adj Close       6547.05
# dtype: object

# %%
df.max()
# Out:
# Date         2016-07-01
# Open            18315.1
# High            18351.4
# Low             18272.6
# Close           18312.4
# Volume        674920000
# Adj Close       18312.4
# dtype: object

# %%
print("df:[open] ",df['Open'].idxmin()) # idxmin return index of first occurence of smallest value
df.iloc[1842]['Open']
# Out:
# df:[open]  1842
# 6547.009765999999

# %%
print("df:[open] ",df['Open'].idxmax()) # idxmxn return index of first occurence of largest value
df.iloc[1842]['Open']
# Out:
# df:[open]  282
# 6547.009765999999

# %%
df.describe()
# Out:
#                Open          High           Low         Close        Volume  \
# count   1989.000000   1989.000000   1989.000000   1989.000000  1.989000e+03
# mean   13459.116048  13541.303173  13372.931728  13463.032255  1.628110e+08
# std     3143.281634   3136.271725   3150.420934   3144.006996  9.392343e+07
# min     6547.009766   6709.609863   6469.950195   6547.049805  8.410000e+06
# 25%    10907.339844  11000.980469  10824.759766  10913.379883  1.000000e+08
# 50%    13022.049805  13088.110352  12953.129883  13025.580078  1.351700e+08
# 75%    16477.699219  16550.070312  16392.769531  16478.410156  1.926000e+08
# max    18315.060547  18351.359375  18272.560547  18312.390625  6.749200e+08
#
#           Adj Close
# count   1989.000000
# mean   13463.032255
# std     3144.006996
# min     6547.049805
# 25%    10913.379883
# 50%    13025.580078
# 75%    16478.410156
# max    18312.390625

# %%
df.mean()
# Out:
# Open         1.345912e+04
# High         1.354130e+04
# Low          1.337293e+04
# Close        1.346303e+04
# Volume       1.628110e+08
# Adj Close    1.346303e+04
# dtype: float64

# %%
df.median()
# Out:
# Open         1.302205e+04
# High         1.308811e+04
# Low          1.295313e+04
# Close        1.302558e+04
# Volume       1.351700e+08
# Adj Close    1.302558e+04
# dtype: float64

# %%
df.var() # variance
# Out:
# Open         9.880219e+06
# High         9.836200e+06
# Low          9.925152e+06
# Close        9.884780e+06
# Volume       8.821610e+15
# Adj Close    9.884780e+06
# dtype: float64

# %%
df.std()
# Out:
# Open         3.143282e+03
# High         3.136272e+03
# Low          3.150421e+03
# Close        3.144007e+03
# Volume       9.392343e+07
# Adj Close    3.144007e+03
# dtype: float64

# %%
df.corr()
# Out:
#                Open      High       Low     Close    Volume  Adj Close
# Open       1.000000  0.999592  0.999436  0.998991 -0.691621   0.998991
# High       0.999592  1.000000  0.999373  0.999546 -0.686997   0.999546
# Low        0.999436  0.999373  1.000000  0.999595 -0.699572   0.999595
# Close      0.998991  0.999546  0.999595  1.000000 -0.694281   1.000000
# Volume    -0.691621 -0.686997 -0.699572 -0.694281  1.000000  -0.694281
# Adj Close  0.998991  0.999546  0.999595  1.000000 -0.694281   1.000000

# %%
df.cummax().head(10)
# Out:
#          Date     Open     High      Low    Close     Volume Adj Close
# 0  2016-07-01  17924.2  18002.4  17916.9  17949.4   82160000   17949.4
# 1  2016-07-01  17924.2  18002.4  17916.9  17949.4  133030000   17949.4
# 2  2016-07-01  17924.2  18002.4  17916.9  17949.4  133030000   17949.4
# 3  2016-07-01  17924.2  18002.4  17916.9  17949.4  133030000   17949.4
# 4  2016-07-01  17924.2  18002.4  17916.9  17949.4  138740000   17949.4
# 5  2016-07-01  17946.6  18002.4  17916.9  17949.4  239000000   17949.4
# 6  2016-07-01  17946.6  18011.1  17916.9  18011.1  239000000   18011.1
# 7  2016-07-01  17946.6  18011.1  17916.9  18011.1  239000000   18011.1
# 8  2016-07-01  17946.6  18011.1  17916.9  18011.1  239000000   18011.1
# 9  2016-07-01  17946.6  18011.1  17916.9  18011.1  239000000   18011.1

# %%
df.cummin().head(10)
# Out:
#          Date     Open     High      Low    Close    Volume Adj Close
# 0  2016-07-01  17924.2  18002.4  17916.9  17949.4  82160000   17949.4
# 1  2016-06-30  17712.8  17930.6  17711.8    17930  82160000     17930
# 2  2016-06-29    17456  17704.5    17456  17694.7  82160000   17694.7
# 3  2016-06-28  17190.5  17409.7  17190.5  17409.7  82160000   17409.7
# 4  2016-06-27  17190.5  17355.2  17063.1  17140.2  82160000   17140.2
# 5  2016-06-24  17190.5  17355.2  17063.1  17140.2  82160000   17140.2
# 6  2016-06-23  17190.5  17355.2  17063.1  17140.2  82160000   17140.2
# 7  2016-06-22  17190.5  17355.2  17063.1  17140.2  82160000   17140.2
# 8  2016-06-21  17190.5  17355.2  17063.1  17140.2  82160000   17140.2
# 9  2016-06-20  17190.5  17355.2  17063.1  17140.2  82160000   17140.2

# %%
len(df)
# Out:
# 1989

# %%
df.isnull().head(10)
# Out:
#     Date   Open   High    Low  Close  Volume  Adj Close
# 0  False  False  False  False  False   False      False
# 1  False  False  False  False  False   False      False
# 2  False  False  False  False  False   False      False
# 3  False  False  False  False  False   False      False
# 4  False  False  False  False  False   False      False
# 5  False  False  False  False  False   False      False
# 6  False  False  False  False  False   False      False
# 7  False  False  False  False  False   False      False
# 8  False  False  False  False  False   False      False
# 9  False  False  False  False  False   False      False

# %%
mySeries = pd.Series([3,-5,7,4], index=['a','b','c','d'])
type(mySeries)

# %%
mySeries['c']
# Out:
# 7

# %%
mySeries[2:]
# Out:
# c    7
# d    4
# dtype: int64

# %%
mySeries[1:3]
# Out:
# b   -5
# c    7
# dtype: int64

# %%
df.iloc[[1],[1]] # [row],[col]
# Out:
#            Open
# 1  17712.759766

# %%
df['Volume'][:10]
# Out:
# 0     82160000
# 1    133030000
# 2    106380000
# 3    112190000
# 4    138740000
# 5    239000000
# 6     98070000
# 7     89440000
# 8     85130000
# 9     99380000
# Name: Volume, dtype: int64

# %%
df['Volume'].nunique() #This code shows how many of the data that is in the selected column and does not repeat.
# Out:
# 1897

# %%
# This code shows which of the data in the selected column repeats.
df['Volume'].unique()
# Out:
# array([ 82160000, 133030000, 106380000, ..., 173590000, 183190000,
#        212830000], dtype=int64)

# %%
# This code counts all of the data in the column we have specified, but does not count the null/none values.
df['Volume'].value_counts(dropna=True)
# Out:
# 76820000     3
# 103260000    3
# 158440000    2
# 76270000     2
# 62770000     2
# 113620000    2
# 85230000     2
# 107100000    2
# 67510000     2
# 143990000    2
# 123070000    2
# 116160000    2
# 177920000    2
# 135940000    2
# 128420000    2
# 99400000     2
# 141870000    2
# 134640000    2
# 131670000    2
# 75090000     2
# 119800000    2
# 145920000    2
# 165880000    2
# 126460000    2
# 131150000    2
# 89440000     2
# 168560000    2
# 90630000     2
# 114360000    2
# 190220000    2
#             ..
# 584900000    1
# 73440000     1
# 149250000    1
# 118950000    1
# 308520000    1
# 195910000    1
# 79330000     1
# 52880000     1
# 319210000    1
# 114590000    1
# 73720000     1
# 95020000     1
# 142030000    1
# 85510000     1
# 106380000    1
# 207200000    1
# 94320000     1
# 126650000    1
# 128020000    1
# 103860000    1
# 65570000     1
# 87420000     1
# 192310000    1
# 64560000     1
# 231160000    1
# 260900000    1
# 121240000    1
# ...

# %%
# This code fetches random n data from the data.
df.sample(10)
# Out:
#             Date          Open          High           Low         Close  \
# 163   2015-11-06  17855.220703  17912.039062  17768.599609  17910.330078
# 637   2013-12-19  16162.509766  16194.719727  16121.540039  16179.080078
# 758   2013-06-28  15016.580078  15034.629883  14884.799805  14909.599609
# 513   2014-06-19  16909.900391  16923.429688  16858.880859  16921.460938
# 137   2015-12-15  17374.779297  17627.630859  17341.179688  17524.910156
# 1030  2012-05-29  12454.830078  12611.610352  12454.599609  12580.690430
# 474   2014-08-14  16657.320312  16714.220703  16651.669922  16713.580078
# 57    2016-04-12  17571.339844  17744.429688  17553.570312  17721.250000
# 547   2014-05-01  16580.259766  16604.789062  16525.250000  16558.869141
# 143   2015-12-07  17845.490234  17845.490234  17639.250000  17730.509766
#
#          Volume     Adj Close
# 163   107450000  17910.330078
# 637    94980000  16179.080078
# 758   230000000  14909.599609
# 513    80220000  16921.460938
# ...

# %%
# This code brings N from the column where we have specified the largest data.
df.nlargest(6,'Volume')
# Out:
#             Date          Open          High           Low         Close  \
# 1944  2008-10-10   8568.669922   8901.280273   7882.509766   8451.190430
# 1834  2009-03-20   7402.310059   7460.930176   7257.830078   7278.379883
# 1849  2009-02-27   7180.970215   7195.459961   7033.620117   7062.930176
# 438   2014-10-06  17010.339844  17099.390625  16930.380859  16991.910156
# 1959  2008-09-19  11027.509766  11483.049805  11026.700195  11388.440430
# 1842  2009-03-10   6547.009766   6926.490234   6546.609863   6926.490234
#
#          Volume     Adj Close
# 1944  674920000   8451.190430
# 1834  672950000   7278.379883
# 1849  667950000   7062.930176
# 438   655450000  16991.910156
# 1959  655110000  11388.440430
# 1842  640020000   6926.490234

# %%
# This code brings N from the column where we have specified the largest data.
df.nsmallest(6,'Volume')
# Out:
#             Date          Open          High           Low         Close  \
# 1133  2011-12-29  12152.320312  12293.959961  12152.089844  12287.040039
# 1163  2011-11-15  12077.919922  12165.110352  12001.259766  12096.160156
# 634   2013-12-24  16295.700195  16360.599609  16295.700195  16357.549805
# 130   2015-12-24  17593.259766  17606.339844  17543.949219  17552.169922
# 382   2014-12-24  18035.730469  18086.240234  18027.779297  18030.210938
# 632   2013-12-27  16486.369141  16529.009766  16461.230469  16478.410156
#
#         Volume     Adj Close
# 1133   8410000  12287.040039
# 1163  14510000  12096.160156
# 634   33640000  16357.549805
# 130   40350000  17552.169922
# 382   42870000  18030.210938
# 632   47230000  16478.410156
