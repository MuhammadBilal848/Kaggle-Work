# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Data Science Courses.csv')
df
# Out:
#                                                    Name                Rating  \
# 0     Complete Machine Learning & Data Science Bootc...  Rating: 4.6 out of 5
# 1     Introduction to Machine Learning for Data Science  Rating: 4.4 out of 5
# 2         NLP - Natural Language Processing with Python  Rating: 4.6 out of 5
# 3     Data Science: Natural Language Processing (NLP...  Rating: 4.6 out of 5
# 4     Statistics for Business Analytics and Data Sci...  Rating: 4.5 out of 5
# ...                                                 ...                   ...
# 2739                       AI/機械学習って何？の基礎がわかる、初心者向け入門講座         37 total mins
# 2740                   [생활코딩] DATABASE - 관계형 데이터 모델링 #2       1.5 total hours
# 2741                         [생활코딩] DATABASE - SQL Join          1 total hour
# 2742                        [생활코딩] WEB - PHP & MySQL #2         2 total hours
# 2743                   [생활코딩] DATABASE - 관계형 데이터 모델링 #1          1 total hour
#
# ...

# %%
df.Rating[1].split(' ')
# Out:
# ['Rating:', '4.4', 'out', 'of', '5']

# %%
df
# Out:
#                                                    Name                Rating  \
# 0     Complete Machine Learning & Data Science Bootc...  Rating: 4.6 out of 5
# 1     Introduction to Machine Learning for Data Science  Rating: 4.4 out of 5
# 2         NLP - Natural Language Processing with Python  Rating: 4.6 out of 5
# 3     Data Science: Natural Language Processing (NLP...  Rating: 4.6 out of 5
# 4     Statistics for Business Analytics and Data Sci...  Rating: 4.5 out of 5
# ...                                                 ...                   ...
# 2739                       AI/機械学習って何？の基礎がわかる、初心者向け入門講座         37 total mins
# 2740                   [생활코딩] DATABASE - 관계형 데이터 모델링 #2       1.5 total hours
# 2741                         [생활코딩] DATABASE - SQL Join          1 total hour
# 2742                        [생활코딩] WEB - PHP & MySQL #2         2 total hours
# 2743                   [생활코딩] DATABASE - 관계형 데이터 모델링 #1          1 total hour
#
# ...
