# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Courses.csv').drop('Unnamed: 0',axis = 1)

# %%
df
# Out:
#                                                  Name Ratings   Duration  \
# 0      Google Data Analytics Professional Certificate   4.8/5   6 Months
# 1           IBM Data Science Professional Certificate   4.6/5  11 Months
# 2           IBM Data Analyst Professional Certificate   4.6/5  11 Months
# 3       IBM Data Engineering Professional Certificate   4.6/5  15 Months
# 4     Meta Database Engineer Professional Certificate     4.6          6
# 5   IBM Data Analytics with Excel and R Profession...     4.7         11
# 6   IBM Data Warehouse Engineer Professional Certi...     4.7          8
# 7                                                 NaN     NaN        NaN
# 8   Microsoft Azure Data Scientist Associate (DP-1...     4.5          7
# 9   Microsoft Azure Data Engineering Associate (DP...     4.4         13
# 10      IBM Machine Learning Professional Certificate     4.6          8
# 11   SAS Advanced Programmer Professional Certificate     4.9          5
# ...

# %%
df.drop([12,17],axis = 0).reset_index(drop= True).to_csv('Courses.csv')
